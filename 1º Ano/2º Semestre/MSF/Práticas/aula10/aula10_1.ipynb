# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Pêndulo Simples

# %%
t0 = 0.0
tf = 10
dt = 0.001
g = 9.8

theta0 = np.radians(10) # 10 * np.pi / 180
w0 = 0.0

L = 1.0

t = np.arange(t0, tf, dt)
y = np.zeros(np.size(t))
w = np.zeros(np.size(t))

theta = np.zeros(np.size(t))

theta[0] = theta0
w[0] = w0

for i in range(np.size(t) - 1):
  y[i] = -g / L * np.sin(theta[i])
  w[i+1] = w[i] + y[i] * dt
  theta[i+1] = theta[i] + w[i + 1] * dt

plt.plot(t, np.degrees(theta), "-b")
plt.xlabel("Tempo decorrido, t [s]")
plt.ylabel("Ângulo, theta [º]")
plt.show()

# %%
T = 2*np.pi*np.sqrt(L / g)
print(f"Período de oscilação, T = {T:.2f} s")
# Out:
# Período de oscilação, T = 2.01 s

# %% [markdown]
# #### b)

# %%
t0 = 0.0
tf = 10
dt = 0.001
g = 9.8

theta0 = np.radians(10) # 10 * np.pi / 180
w0 = 0.0

L = 1.0

t = np.arange(t0, tf, dt)
y = np.zeros(np.size(t))
w = np.zeros(np.size(t))

theta = np.zeros(np.size(t))

theta[0] = theta0
w[0] = w0

for i in range(np.size(t) - 1):
  y[i] = -g / L * np.sin(theta[i])
  w[i+1] = w[i] + y[i] * dt
  theta[i+1] = theta[i] + w[i + 1] * dt

A = np.radians(10)
Q = 0.0
theta_a = A * np.cos(np.sqrt(g / L) * t + Q)

plt.plot(t, np.degrees(theta), "-b", t , np.degrees(theta_a), "r-")
plt.xlabel("Tempo decorrido, t [s]")
plt.ylabel("Ângulo, theta [º]")
plt.legend(["Solução numérica", "Solução analítica"])
plt.show()

# %% [markdown]
# #### c)

# %%
t0 = 0.0
tf = 10
dt = 0.001
g = 9.8

theta0 = np.radians(20) # 10 * np.pi / 180
w0 = 0.0

L = 1.0

t = np.arange(t0, tf, dt)
y = np.zeros(np.size(t))
w = np.zeros(np.size(t))

theta = np.zeros(np.size(t))

theta[0] = theta0
w[0] = w0

for i in range(np.size(t) - 1):
  y[i] = -g / L * np.sin(theta[i])
  w[i+1] = w[i] + y[i] * dt
  theta[i+1] = theta[i] + w[i + 1] * dt

A = np.radians(20)
Q = 0.0
theta_a = A * np.cos(np.sqrt(g / L) * t + Q)

plt.plot(t, np.degrees(theta), "-b", t , np.degrees(theta_a), "r-")
plt.xlabel("Tempo decorrido, t [s]")
plt.ylabel("Ângulo, theta [º]")
plt.legend(["Solução numérica", "Solução analítica"])
plt.show()
