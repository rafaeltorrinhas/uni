# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.

# %%
a = 2.0 # m/s²
va = 70 / 3.6
vib = 0
t = np.linspace(0,30)
xA = va * t 
xP = (a*t*t)/2
x = np.linspace(0,800)
plt.xlabel("tempo (s)")
plt.ylabel("posição (x)")
plt.plot(t,xA,"-")
plt.plot(t,xP)
plt.show()

# %%
tx = 70 / 3.6 # cheguei a isto pelo xA = xP
print(tx)

yx = np.interp(tx, t, xA)
print(yx)
# Out:
# 30.0
# 583.3333333333333

# %% [markdown]
# ## 6.
