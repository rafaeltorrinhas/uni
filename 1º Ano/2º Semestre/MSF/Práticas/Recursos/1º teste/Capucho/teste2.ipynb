# %% [markdown]
# ### 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = t = np.array([0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5,9.5,10.5])
y = s = np.array([0.1,1.4,1.7,6.5,7.7,10.4,19.5,26.1,26.5,45.9,52.5])

N = len(x)
sum_x = np.sum(x)
sum_y = np.sum(y)
sum_xy = np.sum(x*y)
sum_xx = np.sum(x ** 2)
sum_yy = np.sum(y ** 2)

r2 = (N * sum_xy - sum_x * sum_y)**2 / ((N * sum_xx - sum_x**2) * (N * sum_yy - sum_y**2))
m = ((N * sum_xy - sum_x * sum_y)/(N*(sum_xx)-((sum_x)**2)))
b = (((sum_xx * sum_y)-sum_x * sum_xy)/(N*sum_xx-((sum_x)**2)))
dm = np.absolute(m) * np.sqrt((1/r2)-1)/((N-2))
db = dm * np.sqrt(sum_xx/N)

plt.plot(x,y, "o", color = "red")
plt.plot(x, m * x + b, color = "black")
plt.show()

print(f"r² = {r2}\nb = {b}\ndb = {db}\nm = {m}\ndm = {dm}" )


x = np.log10(x)
y = np.log10(y)

N = len(x)

sum_x = np.sum(x)
sum_y = np.sum(y)
sum_xy = np.sum(x*y)
sum_xx = np.sum(x ** 2)
sum_yy = np.sum(y ** 2)

r2 = (N * sum_xy - sum_x * sum_y)**2 / ((N * sum_xx - sum_x**2) * (N * sum_yy - sum_y**2))
m = ((N * sum_xy - sum_x * sum_y)/(N*(sum_xx)-((sum_x)**2)))
b = (((sum_xx * sum_y)-sum_x * sum_xy)/(N*sum_xx-((sum_x)**2)))
dm = np.abs(m) * np.sqrt(((1/r2)-1)/(N-2)) 
db = dm * np.sqrt(sum_xx/N)


plt.plot(x,y, "o", color = "red")
plt.plot(x,m * x + b, color = "black")
plt.show()

print(f"r² = {r2}\nb = {b}\ndb = {db}\nm = {m}\ndm = {dm}" )
# Out:
# r² = 0.8896790414268826
# b = -10.242727272727258
# db = 1.275897790546423
# m = 5.139999999999998
# dm = 0.20110966520542248
# r² = 0.9846982165348642
# b = -0.37518116859485334
# db = 0.06089910886904678
# m = 2.011425052714969
# dm = 0.0835799391576071

# %% [markdown]
# ### 2
